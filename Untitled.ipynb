# %%
import pandas as pd

# %%
gens = pd.read_csv("genericizables46k_0_1.csv")

# %%
gens.describe()
# Out:
#          programmer  sizeOfEquivalenceClass     numBlocks
# count  12008.000000            12008.000000  12008.000000
# mean     529.096186                3.359843      4.962192
# std      282.427803                2.539143      4.325967
# min        0.000000                2.000000      0.000000
# 25%      296.000000                2.000000      3.000000
# 50%      546.000000                2.000000      3.000000
# 75%      763.000000                4.000000      6.000000
# max      999.000000               64.000000     60.000000

# %%
gens.head(10)
# Out:
#                   projectName  programmer   screen  sizeOfEquivalenceClass  \
# 0     p010_055_ex_Player.jail           0  Screen1                       4
# 1   p018_003_ex_Activity.jail           0  Screen1                       5
# 2         p024_041_paint.jail           0  Screen1                       4
# 3         p024_041_paint.jail           0  Screen1                       6
# 4   p045_034_ai2_104_ans.jail           0  Screen1                       2
# 5   p046_033_ai2_106_ans.jail           0  Screen1                       2
# 6   p046_033_ai2_106_ans.jail           0  Screen1                       3
# 7  p047_038_ai2_104_3137.jail           0  Screen1                       2
# 8  p050_057_ai2_106_3137.jail           0  Screen1                       2
# 9  p050_057_ai2_106_3137.jail           0  Screen1                       3
#
#    numBlocks                                              name
# 0          8                 Screen1|Button$ButtonMusic1.Click
# ...

# %%
gens.loc[gens["sizeOfEquivalenceClass"]>10].head(20)
# Out:
#                           projectName  programmer       screen  \
# 111   p008_003_YOUSIFHOMECONTROL.jail          13      Screen1
# 112       p009_035_OYUSIFCONTROL.jail          13      Screen1
# 118        p016_012_controlhouse.jail          13      Screen1
# 122         p022_028_controlgtgt.jail          13      Screen1
# 186                  p012_016_P5.jail          18      Screen1
# 227             p025_022_Class15.jail          25      Screen1
# 228             p025_022_Class15.jail          25      Screen1
# 229             p025_022_Class15.jail          25      Screen1
# 230             p025_022_Class15.jail          25      Screen1
# 396            p024_015_My_Music.jail          44       Bandas
# 399             p025_018_Mymusic.jail          44       Bandas
# 402        p027_014_oooooooooooo.jail          44       Bandas
# 431        p014_012_MyCalculator.jail          49      Screen1
# 597       p050_023_Phobia_Copers.jail          66  main_Screen
# ...

# %%
gens.loc[gens["sizeOfEquivalenceClass"]>30].head(20)
# Out:
#                                projectName  programmer             screen  \
# 1792  p000_019_Countries_and_Capitals.jail         174            Screen1
# 2439                   p014_013_Salud.jail         238            Screen5
# 6722                p011_010_Alphabet.jail         599            Screen1
# 7850            p010_017_Metro_Ramais.jail         681  SupervisorTrafego
# 9518          p024_024_BT_3PiCar_Orig.jail         808            Screen1
#
#       sizeOfEquivalenceClass  numBlocks  \
# 1792                      64          3
# 2439                      31          3
# 6722                      54          3
# 7850                      47          4
# 9518                      32          3
#
#                                                 name
# 1792              Screen1|CheckBox$CheckBox1.Changed
# 2439                  Screen5|Button$pediatria.Click
# 6722                          Screen1|Button$A.Click
# 7850            SupervisorTrafego|Button$Bt_01.Click
# ...
